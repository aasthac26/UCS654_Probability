# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    "/kaggle/input/india-air-quality-data/data.csv",
    encoding="latin1"
)

x = df["no2"].dropna().values

print("Total NO2 samples:", len(x))
r = 102316009
ar = 0.05 * (r % 7)
br = 0.3 * (r % 5 + 1)

print("a_r =", ar)
print("b_r =", br)

z = x + ar * np.sin(br * x)

mu = np.mean(z)

sigma = np.var(z)

lam = 1 / (2 * sigma)
c = 1 / np.sqrt(2 * np.pi * sigma)
print("\nFINAL PARAMETERS ")
print("μ (mu) =", mu)
print("λ (lambda) =", lam)
print("c   =", c)
plt.figure(figsize=(8,5))
plt.hist(z, bins=50, density=True)
plt.title("PDF of Transformed Variable z")
plt.xlabel("z")
plt.ylabel("Probability Density")
plt.show()
# Out:
# /tmp/ipykernel_54/3045198686.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
# Total NO2 samples: 419509
# a_r = 0.25
# b_r = 1.5
#
# FINAL PARAMETERS
# μ (mu) = 25.818063543032295
# λ (lambda) = 0.0014617052940514906
# c   = 0.021570239817484047
